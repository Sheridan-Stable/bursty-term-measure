# %% [markdown]
# # GENIA Data Preprocessing
#
# Authors: Samuel Sarria Hurtado and Uyen Lai and Paul Sheridan
#
# Description: Preprocess the GENIA Term corpus version 3.02 dataset.
#
# Inputs:
# * Raw data (XML): GENIAcorpus3.02.xml
#
# Outputs:
# * Document Ids (CSV): GENIAcorpus3.02-doc-ids.csv
# * Lex/sem mapping (TSV): GENIAcorpus3.02-keywords.tsv
# * Preprocessed documents (JSON): GENIAcorpus3.02-preprocessed.json

# %% [markdown]
# ## Imports

# %%
import json
import numpy as np
import re
import unicodedata
import inflect
import bs4
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Load Helper Functions

# %%
def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

def replace_numbers(words):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = replace_numbers(words)
    return words

def take_out_str(arr, s):
  """Goes through an array of strings and removes substring s from every
  element in the array"""
  for i in range(len(arr)):
    if type(arr[i]) is str:
      if s in arr[i]:
        arr[i] = arr[i].replace(s, '')

# %% [markdown]
# ## Preprocess the Raw Data

# %% [markdown]
# ### Read in the Raw Data

# %%
infile_path = '../0-data-raw/GENIAcorpus3.02-test.xml'
infile = open(infile_path, 'r')
contents = infile.read()
soup = BeautifulSoup(contents, 'xml')

# %% [markdown]
# ### Data Cleaning
#
# Here we eliminate tags, and other elements in the dataset, that might be troublesome. These are:
# * Coordinated lex attributes.
# * Cons tags lacking a sem attribute. Note: that they're all deleted upon deleting the coordinated con tags with a coordinated lex attribute.
# * Cons tags without a lex attribute
# * All instances of the words "(ABSTRACT TRUNCATED AT 250 WORDS)".
# * All instances of the words "(ABSTRACT TRUNCATED AT 400 WORDS)".

# %%
# Extract cons:
all_cons = soup.find_all('cons')
total_cons = len(all_cons)
all_cons = np.array(all_cons, dtype=object)
no_sem = soup.find_all('cons', sem=False)
no_sem_total = len(no_sem)

# Excise coordinated lex attributes:
coordinated_arr = []
for i in range(len(all_cons)):
    if 'sem' in all_cons[i].attrs:
      if '(' in all_cons[i].attrs['sem']:
        coordinated_arr.append(all_cons[i])

total_coordinated = len(coordinated_arr)
for i in range(total_coordinated):
  coordinated_arr[i].decompose()

# Excise cons without lex attributes:
no_lex = soup.find_all('cons', lex=False)
no_lex_total = len(no_lex)
for lex in no_lex:
  lex.decompose()

# Excise truncated at 250 records abstract sentences:
truncated_at_250_words_instances = soup.find_all('sentence', string='(ABSTRACT TRUNCATED AT 250 WORDS)')
truncated_at_250_words_total = len(truncated_at_250_words_instances)
for trunc in truncated_at_250_words_instances:
  trunc.decompose()

# Excise truncated at 400 records abstract sentences:
truncated_at_400_words_instances = soup.find_all('sentence', string='(ABSTRACT TRUNCATED AT 400 WORDS)')
truncated_at_400_words_total = len(truncated_at_400_words_instances)
for trunc in truncated_at_400_words_instances:
  trunc.decompose()

# Summarize results:
print('Total number of cons:', total_cons)
print('Cons tags without sem attribute:', no_sem_total)
print('Proportion of cons tags without sem attribute:', no_sem_total/total_cons)
print('Cons tags without lex attribute:', no_lex_total)
print('Proportion of cons tags without lex attribute:', no_lex_total/total_cons)
print('Number of cons tags with a coordinated sem attribute:', total_coordinated)
print('Proportion of cons tags with a coordinated sem attribute:', total_coordinated/total_cons)
print('Number of \'(ABSTRACT TRUNCATED AT 250 WORDS)\' instance:', truncated_at_250_words_total)
print('Associated proportion:', truncated_at_250_words_total/total_cons)
print('Number of \'(ABSTRACT TRUNCATED AT 400 WORDS)\' instance:', truncated_at_400_words_total)
print('Associated proportion:', truncated_at_400_words_total/total_cons)
# Out:
# Total number of cons: 155
# Cons tags without sem attribute: 3
# Proportion of cons tags without sem attribute: 0.01935483870967742
# Cons tags without lex attribute: 2
# Proportion of cons tags without lex attribute: 0.012903225806451613
# Number of cons tags with a coordinated sem attribute: 1
# Proportion of cons tags with a coordinated sem attribute: 0.0064516129032258064
# Number of '(ABSTRACT TRUNCATED AT 250 WORDS)' instance: 1
# Associated proportion: 0.0064516129032258064
# Number of '(ABSTRACT TRUNCATED AT 400 WORDS)' instance: 0
# Associated proportion: 0.0

# %%
print(all_cons[0:9])
# Out:
# [<cons lex="IL-2_gene_expression" sem="G#other_name"><cons lex="IL-2_gene" sem="G#DNA_domain_or_region">IL-2 gene</cons> expression</cons>
#  <cons lex="IL-2_gene" sem="G#DNA_domain_or_region">IL-2 gene</cons>
#  <cons lex="NF-kappa_B_activation" sem="G#other_name"><cons lex="NF-kappa_B" sem="G#protein_molecule">NF-kappa B</cons> activation</cons>
#  <cons lex="NF-kappa_B" sem="G#protein_molecule">NF-kappa B</cons>
#  <cons lex="CD28" sem="G#protein_molecule">CD28</cons>
#  <cons lex="5-lipoxygenase" sem="G#protein_molecule">5-lipoxygenase</cons>
#  <cons lex="CD28_surface_receptor" sem="G#protein_family_or_group"><cons lex="CD28" sem="G#protein_molecule">CD28</cons> surface receptor</cons>
#  <cons lex="CD28" sem="G#protein_molecule">CD28</cons>
#  <cons lex="T_cell_activation" sem="G#other_name">T cell activation</cons>]

# %% [markdown]
# ### Test
# Test that the above code cell worked. If it worked, all quantities printed (except for the total number of con tags) should be 0.

# %%
cons = soup.find_all('cons')
new_total_cons = len(cons)

new_no_sem = soup.find_all('cons', sem=False)
new_no_sem_total = len(new_no_sem)

new_no_lex = soup.find_all('cons', lex=False)
new_no_lex_total = len(new_no_lex)

truncated_at_250_words_instances = soup.find_all('sentence', string='(ABSTRACT TRUNCATED AT 250 WORDS)')
new_truncated_at_250_words_total = len(truncated_at_250_words_instances)

truncated_at_400_words_instances = soup.find_all('sentence', string='(ABSTRACT TRUNCATED AT 400 WORDS)')
new_truncated_at_400_words_total = len(truncated_at_400_words_instances)

new_coordinated_counter = 0
for i in range(new_total_cons):
  if 'sem' in cons[i].attrs:
    if '(' in cons[i].attrs['sem']:
      new_coordinated_counter += 1

print('Total of con tags now:', new_total_cons)
print('Total of con tags without sem attribute now:', new_no_sem_total)
print('Total of con tags without lex attribute now:', new_no_sem_total)
print('Total instances of abstracts truncated at 250 words now:', new_truncated_at_250_words_total)
print('Total instances of abstracts truncated at 400 words now:', new_truncated_at_400_words_total)
print('Total instances of cons tags with coordinated sem attributes:', new_coordinated_counter)
# Out:
# Total of con tags now: 149
# Total of con tags without sem attribute now: 0
# Total of con tags without lex attribute now: 0
# Total instances of abstracts truncated at 250 words now: 0
# Total instances of abstracts truncated at 400 words now: 0
# Total instances of cons tags with coordinated sem attributes: 0

# %%
print(cons[0:9])
# Out:
# [<cons lex="IL-2_gene_expression" sem="G#other_name"><cons lex="IL-2_gene" sem="G#DNA_domain_or_region">IL-2 gene</cons> expression</cons>, <cons lex="IL-2_gene" sem="G#DNA_domain_or_region">IL-2 gene</cons>, <cons lex="NF-kappa_B_activation" sem="G#other_name"><cons lex="NF-kappa_B" sem="G#protein_molecule">NF-kappa B</cons> activation</cons>, <cons lex="NF-kappa_B" sem="G#protein_molecule">NF-kappa B</cons>, <cons lex="CD28" sem="G#protein_molecule">CD28</cons>, <cons lex="5-lipoxygenase" sem="G#protein_molecule">5-lipoxygenase</cons>, <cons lex="CD28_surface_receptor" sem="G#protein_family_or_group"><cons lex="CD28" sem="G#protein_molecule">CD28</cons> surface receptor</cons>, <cons lex="CD28" sem="G#protein_molecule">CD28</cons>, <cons lex="T_cell_activation" sem="G#other_name">T cell activation</cons>]

# %% [markdown]
# ### Clean up Lex Attributes
# Some lex text contains spaces. This is probably due to annotation errors. We replace spaces with underscores and postfix all lexes with the tag "_lex".

# %%
# Create data frame of lexes and sems:
lex_and_sem = []
for con in cons:
  lex_and_sem.append(con.attrs)
lex_and_sem_df = pd.DataFrame(lex_and_sem)

# For any lexes, substitute space characters for underscores and add '_lex' postfix:
for i in range(len(lex_and_sem_df['lex'])):
    if ' ' in lex_and_sem_df['lex'][i]:
        print(lex_and_sem_df['lex'][i])
        lex_and_sem_df['lex'][i] = lex_and_sem_df['lex'][i].replace(' ', '_')
    lex_and_sem_df['lex'][i] += '_lex'

lex_and_sem_df = lex_and_sem_df.drop_duplicates(subset=['lex'])
lex_and_sem_df = lex_and_sem_df.reset_index(drop=True)

unique_lex = np.array(lex_and_sem_df['lex'])
new_lex_col = take_out_str(lex_and_sem_df['lex'], '\"')
lex_and_sem_df = lex_and_sem_df.replace(lex_and_sem_df['lex'], new_lex_col)

# %%
print(lex_and_sem_df)
# Out:
#                           lex                     sem
# 0    IL-2_gene_expression_lex            G#other_name
# 1               IL-2_gene_lex  G#DNA_domain_or_region
# 2   NF-kappa_B_activation_lex            G#other_name
# 3              NF-kappa_B_lex      G#protein_molecule
# 4                    CD28_lex      G#protein_molecule
# ..                        ...                     ...
# 89            p65_subunit_lex       G#protein_subunit
# 90            p65_protein_lex       G#protein_subunit
# 91              infection_lex            G#other_name
# 92  immunomodulatory_role_lex            G#other_name
# 93          host_response_lex            G#other_name
#
# [94 rows x 2 columns]

# %% [markdown]
# ## Output Files Creation
# Write the three output files:
# * A CSV file containing the document ID'S and their respective doc index
# * A TSV file containing a mapping from each lex to each sem
# * A JSON file containing the preprocessed GENIA Term corpus data. Each element in this JSON file is a list of strings. Some are keywords (if they are in the lex list), some aren't. The words won't be in the same order as the raw data.

# %%
# Get the text in the bibliomisc tags:
doc_id_tags = soup.find_all('bibliomisc')
doc_ids = [id.get_text() for id in doc_id_tags]

# Write the csv file with the doc ids:
csv_outfile_path = 'GENIAcorpus3.02-doc-ids.csv'
index = range(len(doc_ids))
doc_ids_df = pd.DataFrame({'index': index, 'ID': doc_ids})
#doc_ids_df.to_csv(csv_outfile_path, index=False)

# File contents summary:
display(doc_ids_df)
# Out:
#    index                ID
# 0      0  MEDLINE:95369245
# 1      1  MEDLINE:95280913
# 2      2  MEDLINE:99210381

# %%
# Write semantic classes to TSV:
genia_keywords_outfile_path = 'GENIAcorpus3.02-keywords.tsv'
#lex_and_sem_df.to_csv(genia_keywords_outfile_path, index=False, sep='\t')

# File contents summary:
display(lex_and_sem_df)
# Out:
#                           lex                     sem
# 0    IL-2_gene_expression_lex            G#other_name
# 1               IL-2_gene_lex  G#DNA_domain_or_region
# 2   NF-kappa_B_activation_lex            G#other_name
# 3              NF-kappa_B_lex      G#protein_molecule
# 4                    CD28_lex      G#protein_molecule
# ..                        ...                     ...
# 89            p65_subunit_lex       G#protein_subunit
# 90            p65_protein_lex       G#protein_subunit
# 91              infection_lex            G#other_name
# 92  immunomodulatory_role_lex            G#other_name
# 93          host_response_lex            G#other_name
#
# [94 rows x 2 columns]

# %%
# Create JSON file:
xml_articles = soup.find_all('article')

joint_descendants = []
for article in xml_articles:
  joint_descendants.append([descendant for descendant in article.descendants])

j_sen = []
for i in range(len(joint_descendants)):
  j_sen.append([])
  for sen in joint_descendants[i]:
    if sen.name == 'sentence':
      j_sen[i].append(sen)

in_sen = []
for i in range(len(j_sen)):
  in_sen.append([])
  for sentence in j_sen[i]:
    in_sen[i].append([descendant for descendant in sentence.descendants])

#print(len(in_sen))
#print(in_sen[0][0])

in_sentences = []
for i in range(len(in_sen)):
  in_sentences.append([])
  for j in range(len(in_sen[i])):
    for k in range(len(in_sen[i][j])):
      in_sentences[i].append(in_sen[i][j][k])

#print(in_sentences[0])

bag_of_content = []
for i in range(len(in_sentences)):
  bag_of_content.append([])
  for j in range(len(in_sentences[i])):
    if type(in_sentences[i][j]) is bs4.element.Tag:
      bag_of_content[i].append(in_sentences[i][j].attrs)
    elif in_sentences[i][j].parent.name == 'sentence':
      bag_of_content[i].append(in_sentences[i][j])

#print(len(bag_of_content))
#print(len(bag_of_content[0]))
#print(bag_of_content[0])

docs = []
for i in range(len(bag_of_content)):
  docs.append([])
  for j in range(len(bag_of_content[i])):
    word = bag_of_content[i][j]
    print(word)
    if type(word) is dict:
        word = word['lex']
        print("here")
        print(word)
        if ' ' in word:
            word.replace(' ', '_')
        word += '_lex'
        docs[i].append(word)
    else:
        docs[i].append(word)

print(docs[0])
# Out:
# {'lex': 'IL-2_gene_expression', 'sem': 'G#other_name'}
# {'lex': 'IL-2_gene', 'sem': 'G#DNA_domain_or_region'}
#  and
# {'lex': 'NF-kappa_B_activation', 'sem': 'G#other_name'}
# {'lex': 'NF-kappa_B', 'sem': 'G#protein_molecule'}
#  through
# {'lex': 'CD28', 'sem': 'G#protein_molecule'}
#  requires reactive oxygen production by
# {'lex': '5-lipoxygenase', 'sem': 'G#protein_molecule'}
# .
# Activation of the
# {'lex': 'CD28_surface_receptor', 'sem': 'G#protein_family_or_group'}
# {'lex': 'CD28', 'sem': 'G#protein_molecule'}
#  provides a major costimulatory signal for
# {'lex': 'T_cell_activation', 'sem': 'G#other_name'}
#  resulting in enhanced production of
# {'lex': 'interleukin-2', 'sem': 'G#protein_molecule'}
#  (
# {'lex': 'IL-2', 'sem': 'G#protein_molecule'}
# ) and
# {'lex': 'cell_proliferation', 'sem': 'G#other_name'}
# .
# In
# {'lex': 'primary_T_lymphocyte', 'sem': 'G#cell_type'}
#  we show that
# {'lex': 'CD28', 'sem': 'G#protein_molecule'}
#  ligation leads to the rapid intracellular formation of
# {'lex': 'reactive_oxygen_intermediate', 'sem': 'G#inorganic'}
#  (
# {'lex': 'ROI', 'sem': 'G#inorganic'}
# ) which are required for
# {'lex': 'CD28-mediated_activation', 'sem': 'G#other_name'}
# {'lex': 'CD28', 'sem': 'G#protein_molecule'}
#  of the
# {'lex': 'NF-kappa_B', 'sem': 'G#protein_molecule'}
# /
# {'lex': 'CD28-responsive_complex', 'sem': 'G#protein_complex'}
# {'lex': 'CD28', 'sem': 'G#protein_molecule'}
#  and
# {'lex': 'IL-2_expression', 'sem': 'G#other_name'}
# {'lex': 'IL-2', 'sem': 'G#protein_molecule'}
# .
# Delineation of the
# {'lex': 'CD28_signaling_cascade', 'sem': 'G#other_name'}
# {'lex': 'CD28', 'sem': 'G#protein_molecule'}
#  was found to involve
# {'lex': 'protein_tyrosine_kinase_activity', 'sem': 'G#other_name'}
# {'lex': 'protein_tyrosine_kinase', 'sem': 'G#protein_family_or_group'}
# , followed by the activation of
# {'lex': 'phospholipase_A2', 'sem': 'G#protein_molecule'}
#  and
# {'lex': '5-lipoxygenase', 'sem': 'G#protein_molecule'}
# .
# Our data suggest that
# {'lex': 'lipoxygenase_metabolite', 'sem': 'G#protein_family_or_group'}
# {'lex': 'lipoxygenase', 'sem': 'G#protein_molecule'}
#  activate
# {'lex': 'ROI_formation', 'sem': 'G#other_name'}
# {'lex': 'ROI', 'sem': 'G#inorganic'}
#  which then induce
# {'lex': 'IL-2', 'sem': 'G#protein_molecule'}
#  expression via
# {'lex': 'NF-kappa_B_activation', 'sem': 'G#other_name'}
# {'lex': 'NF-kappa_B', 'sem': 'G#protein_molecule'}
# .
# These findings should be useful for
# {'lex': 'therapeutic_strategies', 'sem': 'G#other_name'}
#  and the development of
# {'lex': 'immunosuppressants', 'sem': 'G#other_name'}
#  targeting the
# {'lex': 'CD28_costimulatory_pathway', 'sem': 'G#other_name'}
# {'lex': 'CD28', 'sem': 'G#protein_molecule'}
# .
# {'lex': 'ligand-dependent_repression', 'sem': 'G#other_name'}
#  of the
# {'lex': 'erythroid_transcription_factor', 'sem': 'G#protein_family_or_group'}
#
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
#  by the
# {'lex': 'estrogen_receptor', 'sem': 'G#protein_family_or_group'}
# .
# {'lex': 'high-dose_estrogen_administration', 'sem': 'G#other_name'}
#  induces
# {'lex': 'anemia', 'sem': 'G#other_name'}
#  in
# {'lex': 'mammal', 'sem': 'G#multi_cell'}
# .
# In chickens, estrogens stimulate outgrowth of
# {'lex': 'bone_marrow-derived_erythroid_progenitor_cell', 'sem': 'G#cell_type'}
#  and delay their
# {'lex': 'maturation', 'sem': 'G#other_name'}
# .
# This delay is associated with
# {'lex': 'down-regulation', 'sem': 'G#other_name'}
#  of many
# {'lex': 'erythroid_cell-specific_gene', 'sem': 'G#DNA_family_or_group'}
# , including
# ,
# {'lex': 'band_3', 'sem': 'G#DNA_N/A'}
# ,
# {'lex': 'band_4.1', 'sem': 'G#DNA_N/A'}
# , and the
# {'lex': 'erythroid_cell-specific_histone', 'sem': 'G#protein_molecule'}
#
# {'lex': 'H5', 'sem': 'G#protein_molecule'}
# .
# We show here that estrogens also reduce the number of
# {'lex': 'erythroid_progenitor_cell', 'sem': 'G#cell_type'}
#  in
# {'lex': 'primary_human_bone_marrow_culture', 'sem': 'G#cell_line'}
# .
# To address potential mechanisms by which
# {'lex': 'estrogen', 'sem': 'G#lipid'}
#  suppress
# {'lex': 'erythropoiesis', 'sem': 'G#other_name'}
# , we have examined their effects on
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
# , an
# {'lex': 'erythroid_transcription_factor', 'sem': 'G#protein_family_or_group'}
#  that participates in the regulation of the majority of
# {'lex': 'erythroid_cell-specific_gene', 'sem': 'G#DNA_domain_or_region'}
#  and is necessary for full maturation of
# {'lex': 'erythrocyte', 'sem': 'G#cell_type'}
# .
# We demonstrate that the
# {'lex': 'transcriptional_activity', 'sem': 'G#other_name'}
#  of
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
#  is strongly repressed by the
# {'lex': 'estrogen_receptor', 'sem': 'G#protein_family_or_group'}
#  (
# {'lex': 'ER', 'sem': 'G#protein_family_or_group'}
# ) in a ligand-dependent manner and that this
# {'lex': 'repression', 'sem': 'G#other_name'}
#  is reversible in the presence of
# {'lex': '4-hydroxytamoxifen', 'sem': 'G#other_organic_compound'}
# .
# {'lex': 'ER-mediated_repression', 'sem': 'G#other_name'}
# {'lex': 'ER', 'sem': 'G#protein_family_or_group'}
#  of
# {'lex': 'GATA-1_activity', 'sem': 'G#other_name'}
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
#  occurs on an
# {'lex': 'artificial_promoter', 'sem': 'G#DNA_molecule'}
#  containing a single
# {'lex': 'GATA-binding_site', 'sem': 'G#DNA_domain_or_region'}
# , as well as in the context of an
# {'lex': 'intact_promoter', 'sem': 'G#DNA_domain_or_region'}
#  which is normally regulated by
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
# .
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
#  and
# {'lex': 'ER', 'sem': 'G#protein_family_or_group'}
#  bind to each other in vitro in the absence of DNA.
# In
# {'lex': 'coimmunoprecipitation_experiment', 'sem': 'G#other_name'}
#  using transfected
# {'lex': 'COS_cell', 'sem': 'G#cell_line'}
# ,
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
#  and
# {'lex': 'ER', 'sem': 'G#protein_family_or_group'}
#  associate in a
# {'lex': 'ligand-dependent_manner', 'sem': 'G#other_name'}
# .
# Mapping experiments indicate that
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
#  and the
# {'lex': 'ER', 'sem': 'G#protein_family_or_group'}
#  form at least two contacts, which involve the finger region and the
# {'lex': 'N-terminal_activation_domain', 'sem': 'G#protein_domain_or_region'}
#  of
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
# .
# We speculate that
# {'lex': 'estrogen', 'sem': 'G#lipid'}
#  exert effects on
# {'lex': 'erythropoiesis', 'sem': 'G#other_name'}
#  by modulating
# {'lex': 'GATA-1_activity', 'sem': 'G#other_name'}
# {'lex': 'GATA-1', 'sem': 'G#protein_molecule'}
#  through
# {'lex': 'protein-protein_interaction', 'sem': 'G#other_name'}
#  with the
# {'lex': 'ER', 'sem': 'G#protein_family_or_group'}
# .
# Activation of
# {'lex': 'NF-kappaB', 'sem': 'G#protein_complex'}
#  in
# {'lex': 'Mycobacterium_tuberculosis-_induced_interleukin-2_receptor_expression', 'sem': 'G#other_name'}
# {'lex': 'Mycobacterium_tuberculosis', 'sem': 'G#mono_cell'}
# {'lex': 'interleukin-2_receptor', 'sem': 'G#protein_molecule'}
#  in
# {'lex': 'mononuclear_phagocyte', 'sem': 'G#cell_type'}
# .
# Soluble
# {'lex': 'interleukin-2_receptor-alpha', 'sem': 'G#protein_molecule'}
# {'lex': 'interleukin-2_receptor', 'sem': 'G#protein_molecule'}
#  (
# {'lex': 'IL-2Ralpha', 'sem': 'G#protein_molecule'}
# ) has been reported to be increased in the sera of patients with advanced tuberculosis, and levels decline after therapy in accordance with improvement of
# {'lex': 'radiologic_finding', 'sem': 'G#other_name'}
# .
# We investigated expression of the
# {'lex': 'IL-2Ralpha', 'sem': 'G#protein_molecule'}
#  in
# {'lex': 'bronchoalveolar_lavage_(BAL)_cell', 'sem': 'G#cell_type'}
#  in
# {'lex': 'active_pulmonary_tuberculosis', 'sem': 'G#other_name'}
# , and evaluated the mechanism
# {'lex': 'Mycobacterium_tuberculosis', 'sem': 'G#mono_cell'}
#  induces in the
# {'lex': 'IL-2Ralpha', 'sem': 'G#protein_molecule'}
#  using the
# .
# We found
# {'lex': 'IL-2Ralpha_expression', 'sem': 'G#other_name'}
# {'lex': 'IL-2Ralpha', 'sem': 'G#protein_molecule'}
#  to be increased in BAL cells from involved sites of
# {'lex': 'active_pulmonary_tuberculosis', 'sem': 'G#other_name'}
# .
# Expression of the
# {'lex': 'alpha-chain', 'sem': 'G#protein_subunit'}
#  of
# {'lex': 'IL-2Ralpha', 'sem': 'G#protein_molecule'}
#  on
# {'lex': 'peripheral_blood_monocyte', 'sem': 'G#cell_type'}
#  (
# {'lex': 'PBM', 'sem': 'G#cell_type'}
# ) was induced by
# {'lex': 'M._tuberculosis', 'sem': 'G#mono_cell'}
#  by flow cytometry evaluation.
# Northern analysis demonstrated increased
# {'lex': 'IL-2Ralpha_gene_expression', 'sem': 'G#other_name'}
# {'lex': 'IL-2Ralpha', 'sem': 'G#protein_molecule'}
#  after stimulation with
# {'lex': 'M._tuberculosis', 'sem': 'G#mono_cell'}
#  which was further induced by
# {'lex': 'interferon-gamma', 'sem': 'G#protein_molecule'}
#  (
# {'lex': 'IFN-gamma', 'sem': 'G#protein_molecule'}
# ).
# The
# {'lex': 'IL-2Ralpha_promoter', 'sem': 'G#DNA_domain_or_region'}
# {'lex': 'IL-2Ralpha', 'sem': 'G#protein_molecule'}
#  containing the
# {'lex': 'nuclear_factor_kappa_B_(NF-kappaB)_site', 'sem': 'G#DNA_domain_or_region'}
# {'lex': 'nuclear_factor_kappa_B', 'sem': 'G#protein_complex'}
# {'lex': 'NF-kappaB', 'sem': 'G#protein_complex'}
#  was transcriptionally induced by
# {'lex': 'M._tuberculosis', 'sem': 'G#mono_cell'}
#  and this
# {'lex': 'NF-kappaB', 'sem': 'G#protein_complex'}
#  site could confer inducibility to a
# {'lex': 'heterologous_herpes_thymidine_kinase_(TK)_promoter', 'sem': 'G#DNA_domain_or_region'}
# {'lex': 'thymidine_kinase', 'sem': 'G#protein_family_or_group'}
# {'lex': 'thymidine', 'sem': 'G#amino_acid_monomer'}
#  by
# {'lex': 'M._tuberculosis', 'sem': 'G#mono_cell'}
# .
# {'lex': 'electrophoretic_mobility_shift_assay', 'sem': 'G#other_name'}
#  (
# {'lex': 'EMSA', 'sem': 'G#other_name'}
# ) revealed specific binding of nuclear protein to the
# {'lex': 'NF-kappaB_site', 'sem': 'G#DNA_domain_or_region'}
# {'lex': 'NF-kappaB', 'sem': 'G#protein_complex'}
#  upon induction with
# {'lex': 'M._tuberculosis', 'sem': 'G#mono_cell'}
# .
# Using antibodies against the
# {'lex': 'p50', 'sem': 'G#protein_subunit'}
#  and
# {'lex': 'p65_subunit', 'sem': 'G#protein_subunit'}
#  of
# {'lex': 'NF-kappaB', 'sem': 'G#protein_complex'}
#  in
# {'lex': 'EMSA', 'sem': 'G#other_name'}
# , the involvement of both
# {'lex': 'p50', 'sem': 'G#protein_subunit'}
#  and
# {'lex': 'p65_protein', 'sem': 'G#protein_subunit'}
#  was further demonstrated.
# Functional expression of the
# {'lex': 'IL-2Ralpha', 'sem': 'G#protein_molecule'}
#  on
# {'lex': 'mononuclear_phagocyte', 'sem': 'G#cell_type'}
#  in
# {'lex': 'M._tuberculosis', 'sem': 'G#mono_cell'}
#
# {'lex': 'infection', 'sem': 'G#other_name'}
#  may play an important
# {'lex': 'immunomodulatory_role', 'sem': 'G#other_name'}
#  in the
# {'lex': 'host_response', 'sem': 'G#other_name'}
# .
# [{'lex': 'IL-2_gene_expression', 'sem': 'G#other_name'}, {'lex': 'IL-2_gene', 'sem': 'G#DNA_domain_or_region'}, ' and ', {'lex': 'NF-kappa_B_activation', 'sem': 'G#other_name'}, {'lex': 'NF-kappa_B', 'sem': 'G#protein_molecule'}, ' through ', {'lex': 'CD28', 'sem': 'G#protein_molecule'}, ' requires reactive oxygen production by ', {'lex': '5-lipoxygenase', 'sem': 'G#protein_molecule'}, '.', 'Activation of the ', {'lex': 'CD28_surface_receptor', 'sem': 'G#protein_family_or_group'}, {'lex': 'CD28', 'sem': 'G#protein_molecule'}, ' provides a major costimulatory signal for ', {'lex': 'T_cell_activation', 'sem': 'G#other_name'}, ' resulting in enhanced production of ', {'lex': 'interleukin-2', 'sem': 'G#protein_molecule'}, ' (', {'lex': 'IL-2', 'sem': 'G#protein_molecule'}, ') and ', {'lex': 'cell_proliferation', 'sem': 'G#other_name'}, '.', 'In ', {'lex': 'primary_T_lymphocyte', 'sem': 'G#cell_type'}, ' we show that ', {'lex': 'CD28', 'sem': 'G#protein_molecule'}, ' ligation leads to the rapid intracellular formation of ', {'lex': 'reactive_oxygen_intermediate', 'sem': 'G#inorganic'}, ' (', {'lex': 'ROI', 'sem': 'G#inorganic'}, ') which are required for ', {'lex': 'CD28-mediated_activation', 'sem': 'G#other_name'}, {'lex': 'CD28', 'sem': 'G#protein_molecule'}, ' of the ', {'lex': 'NF-kappa_B', 'sem': 'G#protein_molecule'}, '/', {'lex': 'CD28-responsive_complex', 'sem': 'G#protein_complex'}, {'lex': 'CD28', 'sem': 'G#protein_molecule'}, ' and ', {'lex': 'IL-2_expression', 'sem': 'G#other_name'}, {'lex': 'IL-2', 'sem': 'G#protein_molecule'}, '.', 'Delineation of the ', {'lex': 'CD28_signaling_cascade', 'sem': 'G#other_name'}, {'lex': 'CD28', 'sem': 'G#protein_molecule'}, ' was found to involve ', {'lex': 'protein_tyrosine_kinase_activity', 'sem': 'G#other_name'}, {'lex': 'protein_tyrosine_kinase', 'sem': 'G#protein_family_or_group'}, ', followed by the activation of ', {'lex': 'phospholipase_A2', 'sem': 'G#protein_molecule'}, ' and ', {'lex': '5-lipoxygenase', 'sem': 'G#protein_molecule'}, '.', 'Our data suggest that ', {'lex': 'lipoxygenase_metabolite', 'sem': 'G#protein_family_or_group'}, {'lex': 'lipoxygenase', 'sem': 'G#protein_molecule'}, ' activate ', {'lex': 'ROI_formation', 'sem': 'G#other_name'}, {'lex': 'ROI', 'sem': 'G#inorganic'}, ' which then induce ', {'lex': 'IL-2', 'sem': 'G#protein_molecule'}, ' expression via ', {'lex': 'NF-kappa_B_activation', 'sem': 'G#other_name'}, {'lex': 'NF-kappa_B', 'sem': 'G#protein_molecule'}, '.', 'These findings should be useful for ', {'lex': 'therapeutic_strategies', 'sem': 'G#other_name'}, ' and the development of ', {'lex': 'immunosuppressants', 'sem': 'G#other_name'}, ' targeting the ', {'lex': 'CD28_costimulatory_pathway', 'sem': 'G#other_name'}, {'lex': 'CD28', 'sem': 'G#protein_molecule'}, '.']

# %%
# Create JSON file:
xml_articles = soup.find_all('article')

joint_descendants = []
for article in xml_articles:
  joint_descendants.append([descendant for descendant in article.descendants])

j_sen = []
for i in range(len(joint_descendants)):
  j_sen.append([])
  for sen in joint_descendants[i]:
    if sen.name == 'sentence':
      j_sen[i].append(sen)

in_sen = []
for i in range(len(j_sen)):
  in_sen.append([])
  for sentence in j_sen[i]:
    in_sen[i].append([descendant for descendant in sentence.descendants])

in_sentences = []
for i in range(len(in_sen)):
  in_sentences.append([])
  for j in range(len(in_sen[i])):
    for k in range(len(in_sen[i][j])):
      in_sentences[i].append(in_sen[i][j][k])

bag_of_content = []
for i in range(len(in_sentences)):
  bag_of_content.append([])
  for j in range(len(in_sentences[i])):
    if type(in_sentences[i][j]) is bs4.element.Tag:
      bag_of_content[i].append(in_sentences[i][j].attrs)
    elif in_sentences[i][j].parent.name == 'sentence':
      bag_of_content[i].append(in_sentences[i][j])

keywords = []
stopwords = []
for i in range(len(bag_of_content)):
  keywords.append([])
  stopwords.append([])
  for j in range(len(bag_of_content[i])):
    if type(bag_of_content[i][j]) is dict:
        keywords[i].append(bag_of_content[i][j]['lex'])
    else:
        stopwords[i].append(bag_of_content[i][j])

for i in range(len(keywords)):
    for j in range(len(keywords[i])):
        if ' ' in keywords[i][j]:
            keywords[i][j] = keywords[i][j].replace(' ', '_')
        keywords[i][j] += '_lex'


for i in range(len(stopwords)):
  stopwords[i] = normalize(stopwords[i])
  stopwords[i] = [word.strip() for word in stopwords[i]]
  stopwords[i] = [word for word in stopwords[i] if len(word) > 0]

combined = []
for i in range(len(stopwords)):
  combined.append(keywords[i] + stopwords[i])

genia = []
for doc in combined:
  genia.append(' '.join(doc))

take_out_str(genia, '\"')

# %%
# Write JSON to file:
genia_terms_outfile_path = 'GENIAcorpus3.02-preprocessed.json'
with open(genia_terms_outfile_path, 'w') as outfile:
    json.dump(genia, outfile)
