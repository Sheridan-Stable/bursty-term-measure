# %% [markdown]
# # GENIA Corpus Keyword Extraction with KeyBERT
#
# Authors: Uyen "Rachel" Lai and Paul Sheridan
#
# Description: Extract GENIA Corpus abstract keywords using KeyBERT and calculate associated importance scores.

# %%
# Imports
import json
from keybert import KeyBERT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Imports
#       2 import json
# ----> 3 from keybert import KeyBERT
#
# ModuleNotFoundError: No module named 'keybert'

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.9.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from keybert) (1.25.2)
# Collecting rich>=10.4.0
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scikit-learn>=0.22.2 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from keybert) (1.3.0)
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence_transformers-5.6.0-py3-none-any.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.4/596.4 kB 7.4 MB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from rich>=10.4.0->keybert) (2.20.0)
# Requirement already satisfied: scipy>=1.5.0 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keybert) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keybert) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keybert) (3.6.0)
# Collecting transformers<6.0.0,>=4.41.0
#   Downloading transformers-5.12.1-py3-none-any.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 6.2 MB/s eta 0:00:0000:0100:01
# Collecting huggingface-hub>=0.23.0
#   Downloading huggingface_hub-1.20.1-py3-none-any.whl (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 6.6 MB/s eta 0:00:00a 0:00:01
# Collecting torch>=1.11.0
#   Downloading torch-2.12.1-cp311-cp311-macosx_14_0_arm64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 6.4 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keybert) (4.66.4)
# Requirement already satisfied: click>=8.4.0 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (8.4.1)
# Collecting filelock>=3.10.0
#   Downloading filelock-3.29.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 3.9 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2026.6.0-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.9/203.9 kB 7.5 MB/s eta 0:00:00
# Collecting hf-xet<2.0.0,>=1.5.1
#   Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 8.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (6.0.3)
# Collecting typer<0.26.0,>=0.20.0
#   Downloading typer-0.25.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.3 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: setuptools<82 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (65.5.0)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 9.2 MB/s eta 0:00:0000:0100:01
# Collecting networkx>=2.5.1
#   Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 6.5 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: jinja2 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.1.6)
# Requirement already satisfied: regex>=2025.10.22 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (2026.5.9)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 5.8 MB/s eta 0:00:0000:0100:01
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl (484 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.6/484.6 kB 7.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: anyio in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (4.14.0)
# Requirement already satisfied: certifi in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (1.0.9)
# Requirement already satisfied: idna in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=0.3.8->keybert) (0.16.0)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pasheridan/Desktop/github-repos/bursty-term-measure/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.0.3)
# Installing collected packages: mpmath, sympy, shellingham, safetensors, networkx, mdurl, hf-xet, fsspec, filelock, annotated-doc, torch, markdown-it-py, rich, typer, huggingface-hub, tokenizers, transformers, sentence-transformers, keybert
# Successfully installed annotated-doc-0.0.4 filelock-3.29.4 fsspec-2026.6.0 hf-xet-1.5.1 huggingface-hub-1.20.1 keybert-0.9.0 markdown-it-py-4.2.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.6.1 rich-15.0.0 safetensors-0.8.0 sentence-transformers-5.6.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.12.1 transformers-5.12.1 typer-0.25.1
# WARNING: There was an error checking the latest version of pip.

# %%
import json
from keybert import KeyBERT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import json
# ----> 2 from keybert import KeyBERT
#
# ModuleNotFoundError: No module named 'keybert'

# %%
infile_path = '../1-preprocessing/GENIAcorpus3.02-preprocessed-merged.json'

with open(infile_path, 'r') as file:
    # Load the JSON contents into a Python variable
    data = json.load(file)

# %%
print(data)
# Out:
# ['IL-2_gene_expression IL-2_gene and NF-kappa_B_activation NF-kappa_B through CD28 requires reactive oxygen production by 5-lipoxygenase. Activation of the CD28_surface_receptor CD28 provides a major costimulatory signal for T_cell_activation resulting in enhanced production of interleukin-2 (IL-2) and cell_proliferation. In primary_T_lymphocyte we show that CD28 ligation leads to the rapid intracellular formation of reactive_oxygen_intermediate (ROI) which are required for CD28-mediated_activation CD28 of the NF-kappa_B / CD28-responsive_complex CD28 and IL-2_expression IL-2. Delineation of the CD28_signaling_cascade CD28 was found to involve protein_tyrosine_kinase_activity protein_tyrosine_kinase, followed by the activation of phospholipase_A2 and 5-lipoxygenase. Our data suggest that lipoxygenase_metabolite lipoxygenase activate ROI_formation ROI which then induce IL-2 expression via NF-kappa_B_activation NF-kappa_B. These findings should be useful for therapeutic_strategies and the development of immunosuppressants targeting the CD28_costimulatory_pathway CD28.', 'ligand-dependent_repression of the erythroid_transcription_factor GATA-1 by the estrogen_receptor. high-dose_estrogen_administration induces anemia in mammal. In chickens, estrogens stimulate outgrowth of bone_marrow-derived_erythroid_progenitor_cell and delay their maturation. This delay is associated with down-regulation of many erythroid_cell-specific_gene, including , band_3, band_4.1, and the erythroid_cell-specific_histone H5. We show here that estrogens also reduce the number of erythroid_progenitor_cell in primary_human_bone_marrow_culture. To address potential mechanisms by which estrogen suppress erythropoiesis, we have examined their effects on GATA-1, an erythroid_transcription_factor that participates in the regulation of the majority of erythroid_cell-specific_gene and is necessary for full maturation of erythrocyte. We demonstrate that the transcriptional_activity of GATA-1 is strongly repressed by the estrogen_receptor (ER) in a ligand-dependent manner and that this repression is reversible in the presence of 4-hydroxytamoxifen. ER-mediated_repression ER of GATA-1_activity GATA-1 occurs on an artificial_promoter containing a single GATA-binding_site, as well as in the context of an intact_promoter which is normally regulated by GATA-1. GATA-1 and ER bind to each other in vitro in the absence of DNA. In coimmunoprecipitation_experiment using transfected COS_cell, GATA-1 and ER associate in a ligand-dependent_manner. Mapping experiments indicate that GATA-1 and the ER form at least two contacts, which involve the finger region and the N-terminal_activation_domain of GATA-1. We speculate that estrogen exert effects on erythropoiesis by modulating GATA-1_activity GATA-1 through protein-protein_interaction with the ER.', 'Activation of NF-kappaB in Mycobacterium_tuberculosis-_induced_interleukin-2_receptor_expression Mycobacterium_tuberculosis interleukin-2_receptor in mononuclear_phagocyte. Soluble interleukin-2_receptor-alpha interleukin-2_receptor (IL-2Ralpha) has been reported to be increased in the sera of patients with advanced tuberculosis, and levels decline after therapy in accordance with improvement of radiologic_finding. We investigated expression of the IL-2Ralpha in bronchoalveolar_lavage_(BAL)_cell in active_pulmonary_tuberculosis, and evaluated the mechanism Mycobacterium_tuberculosis induces in the IL-2Ralpha using the . We found IL-2Ralpha_expression IL-2Ralpha to be increased in BAL cells from involved sites of active_pulmonary_tuberculosis. Expression of the alpha-chain of IL-2Ralpha on peripheral_blood_monocyte (PBM) was induced by M._tuberculosis by flow cytometry evaluation. Northern analysis demonstrated increased IL-2Ralpha_gene_expression IL-2Ralpha after stimulation with M._tuberculosis which was further induced by interferon-gamma (IFN-gamma). The IL-2Ralpha_promoter IL-2Ralpha containing the nuclear_factor_kappa_B_(NF-kapp ...

# %%
kw_model = KeyBERT()
for doc in data:
   print("------------------------------------------------------------------------")
   #doc_processed = text.replace("-", "__")
   bag_of_words = kw_model.extract_keywords(doc_preprocessed, keyphrase_ngram_range=(1, 1), stop_words='english',top_n=25, highlight=True)
   for bag in bag_of_words:
         print(bag[0],bag[1] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 kw_model = KeyBERT()
#       2 for doc in data:
#       3    print("------------------------------------------------------------------------")
#
# NameError: name 'KeyBERT' is not defined
